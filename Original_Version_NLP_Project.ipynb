# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install Google

# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 45.3 MB/s
# ...
#      |████████████████████████████████| 895 kB 73.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 57.1 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 5.1 MB/s
# ...

# %%
# !pip install -U tensorflow

# %%
pip install tensorflow_text
# Out:
# ...
#      |████████████████████████████████| 4.4 MB 5.1 MB/s
# ...

# %%
pip install tf-models-official
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 99 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 43 kB 164 kB/s
# ...
#      |████████████████████████████████| 213 kB 52.3 MB/s
# ...
#      |████████████████████████████████| 90 kB 9.6 MB/s
# ...
#      |████████████████████████████████| 352 kB 25.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 59.1 MB/s
# ...
#      |████████████████████████████████| 37.1 MB 46 kB/s
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22258 sha256=2d994741642ed0538c18225071f97651964b3d9d938351d87a4baa382f1dba1f
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=d81fb1b7d1ac40cd584230958d3d5df0765cbc4ca3054f7762d7fa48f7113669
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# ...

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
from nltk import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import seaborn as sns
import itertools
from nltk.corpus import wordnet
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
from nltk.corpus import movie_reviews
from nltk.util import ngrams
from collections import Counter
import statistics 
from collections import defaultdict
from sklearn.decomposition import TruncatedSVD
from gensim.models import Word2Vec
from gensim.test.utils import datapath
from sklearn.metrics.pairwise import cosine_similarity,euclidean_distances
import os
import pickle
from scipy.stats import kendalltau, pearsonr
import tarfile
import re
import numpy as np
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
from nltk import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import seaborn as sns
import itertools
from nltk.corpus import wordnet
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
from nltk.corpus import movie_reviews
from nltk.util import ngrams
from collections import Counter
import statistics 
from collections import defaultdict
from sklearn.decomposition import TruncatedSVD
from gensim.models import Word2Vec
from gensim.test.utils import datapath
from sklearn.metrics.pairwise import cosine_similarity,euclidean_distances
import os
import re
from scipy.stats import kendalltau, pearsonr
from transformers import AutoTokenizer, TFAutoModel
from keras import Sequential
from keras.layers import Bidirectional
from keras.layers import Embedding, Dense, LSTM, RNN,GRU, Bidirectional, Conv1D,MaxPooling1D,Flatten
from sklearn.metrics import classification_report
from keras.preprocessing.sequence import pad_sequences
#from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras import regularizers
from nltk.tokenize import TweetTokenizer
from transformers import TFBertModel, TFAlbertModel, TFRobertaModel,TFDistilBertModel
from transformers import BertTokenizer, AlbertTokenizer,RobertaTokenizer, DistilBertTokenizer
import tensorflow as tf
import tensorflow_hub as hub
import os
import shutil
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from official.nlp import optimization  
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import text_to_word_sequence
from tensorflow.keras.optimizers import Adam 


from keras.preprocessing.text import one_hot
from keras.preprocessing.text import text_to_word_sequence


nltk.download('stopwords')
nltk.download('movie_reviews')
Stopwords=stopwords.words()
nltk.download('wordnet')
nltk.download('punkt')
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
nltk.download('averaged_perceptron_tagger')
wn_lemmas = set(wordnet.all_lemma_names())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
def cleaningFu(fileString):
  lines = fileString.readlines()
  linesList = list ()

  for line in lines:
    #print(line)
    linesList.append(line)

  listOfAuthers=list()
  listOfText=list()

  for text in linesList:
    if (text.startswith('<AUTHOR>')):
      text=text.replace('<AUTHOR>','')
      text=text.replace('</AUTHOR>\n','')
      listOfAuthers.append(text)
    if (text.startswith('<TEXT>')):
      text=text.replace('<TEXT>','')
      text=text.replace('</TEXT>\n','')
      #print(type(text))
      listOfText.append(text)

    
  res = dict(zip(listOfAuthers, listOfText))
  return res

# %%
import os
directory="/content/drive/My Drive/NLP/2007/"
listOfFiles=list()


for filename in os.listdir(directory):
  listOfFiles.append(filename)
listOfFiles.pop(2)
listOfFiles.remove('2007_chevrolet_trailblazer')
listOfFiles.remove('2007_dodge_caliber')
listOfFiles.remove('2007_ford_expedition')
listOfFiles.remove('2007_ford_mustang')
listOfFiles.remove('2007_honda_civic')
listOfFiles.remove('2007_hyundai_santa_fe')
listOfFiles.remove('2007_mazda_mazdaspeed_mazda3')
listOfFiles.remove('2007_mercedes-benz_s-class')
listOfFiles.remove('2007_pontiac_solstice')
listOfFiles.remove('2007_volkswagen_passat')

test=0
listOfDirectories=list()
for files in listOfFiles:
  directoryStr="/content/drive/My Drive/NLP/2007/"
  directoryStr+=files
  file1= open(directoryStr,'r')
  if(test == 0):
    print(file1.readlines())
    test=1  
  dict1=cleaningFu(file1)
  listOfDirectories.append(dict1)
# Out:
# ['<DOCNO>2007_acura_tl</DOCNO>\n', '<DOC>\n', '<DATE>09/11/2009</DATE>\n', '<AUTHOR>rkahrmann</AUTHOR>\n', '<TEXT>I really love my Acura TL-Type S. The fit and finish of this car is really nice. Every time I walk out and get into the car I look forward to turning the ignition key. It drives very well on the open road and the freeway. We took a 6K+ trip this summer and the car turned out to really be a great touring sedan. I think it is the best looking car on the road on the outside. I find the seats comfortable. Braking is superb. Overall I think it is one of the best designs ever. If you can pick up a used one, what a great value it will be.</TEXT>\n', '<FAVORITE>Strong pulling power when passing on two lane road. Comfortable seats and very nice leather. Navigation system screen placement is awesome. Best looking car on the road.</FAVORITE>\n', '</DOC>\n', '<DOC>\n', '<DATE>09/02/2009</DATE>\n', '<AUTHOR>BMR ETR</AUTHOR>\n', '<TEXT>This is my 2nd TL - love the style. Also have a 20
# ...

# %%
def wordTokenize (sentence):
  finalList=list()
  newSentence=word_tokenize(sentence[0])
  for i in newSentence:
    if i in wn_lemmas:
      finalList.append(i)
  return finalList 

def plot_sns(raw_data):
  data = np.array(raw_data)

  x = np.arange(len(raw_data))
  width = 0.2  

  sns.axes_style('white')
  sns.set_style('white')

  ax = sns.barplot(x, data[:,0])
def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN



def ngramFunc(corpus,ngramValue):
  newCorpust=Counter([])
  for review in corpus:
    newReview=list()
    for word in review:
      if (word.isalpha()):
        newReview.append(word)
    newCorpust +=Counter(ngrams(newReview, ngramValue))
  d = {}
  for key, value in newCorpust.items():
    d[key] = value  
  return d

def getAffVal(sentece,corp):
  listOfAff=list(corp.Word)
  listOfWordsAff=list()
  valence=0
  for word in sentece:
    if (word in listOfAff):
      listOfWordsAff.append(word)
  for word in listOfWordsAff:
    valence+=list(afn.loc[afn['Word'] == word].Valence)[0]
  valence=valence/len(listOfWordsAff)
  return listOfWordsAff,valence

def getAro(sentece,corp):
  listOfAff=list(corp.Word)
  listOfWordsAff=list()
  aro=0
  for word in sentece:
    if (word in listOfAff):
      listOfWordsAff.append(word)
  for word in listOfWordsAff:
    aro+=list(afn.loc[afn['Word'] == word].Arousal)[0]
  aro=aro/len(listOfWordsAff)
  return aro

def getDom(sentece,corp):
  listOfAff=list(corp.Word)
  listOfWordsAff=list()
  dom=0
  for word in sentece:
    if (word in listOfAff):
      listOfWordsAff.append(word)
  for word in listOfWordsAff:
    dom+=list(afn.loc[afn['Word'] == word].Dominance)[0]
  dom=dom/len(listOfWordsAff)
  return dom

def load_embeddings(file_name, vocabulary):
 """
 Loads word embeddings from the file with the given name.
 :param file_name: name of the file containing word embeddings
 :type file_name: str
 :param vocabulary: captions vocabulary
 :type vocabulary: numpy.array
 :return: word embeddings
 :rtype: dict
 """
 embeddings = dict()
 with open(file_name, 'r', encoding='utf-8') as doc:
    line = doc.readline()
    while line != '':
      line = line.rstrip('\n').lower()
      parts = line.split(' ')
      vals = np.array(parts[1:], dtype=np.float)
      if parts[0] in vocabulary:
        embeddings[parts[0]] = vals
      line = doc.readline()
 return embeddings


def load_embedding_weights(vocabulary, embedding_size):
 """
 Creates and loads embedding weights.
 :param vocabulary: captions vocabulary
 :type vocabulary: numpy.array
 :param embedding_size: embedding size
 :type embedding_size: int
 :return: embedding weights
 :rtype: numpy.array
 """
 if os.path.exists('/content/drive/My Drive/NLP/embedding_matrix.pkl'):
    with open('/content/drive/My Drive/NLP/embedding_matrix.pkl', 'rb') as f:
        embedding_matrix = pickle.load(f)
 else:
    print('Creating embedding weights...')
    embeddings = load_embeddings(f'/content/drive/My Drive/NLP/glove.6B.{embedding_size}d.txt',
vocabulary)
    embedding_matrix = np.zeros((len(vocabulary), embedding_size))
    for i in range(len(vocabulary)):
        if vocabulary[i] in embeddings.keys():
            embedding_matrix[i] = embeddings[vocabulary[i]]
        else:
            embedding_matrix[i] = np.random.standard_normal(embedding_size)
    with open('/content/drive/My Drive/NLP/embedding_matrix.pkl', 'wb') as f:
        pickle.dump(embedding_matrix, f)
 return embedding_matrix    

 def getSizeOfVocab(vocab):
  vocab=list(vocab)
  resultList=list()
  for line in vocab:
    listLine=list(line)
    resultList.extend(listLine)
  size=list(set(resultList))
  return size[-1:]

def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10000])
  plt.xlabel('Epoch')
  plt.ylabel('Error [MPG]')
  plt.legend()
  plt.grid(True)

# %%
listOfAllLines=list(listOfDirectories[0].values())

for i in listOfDirectories:
  listOfAllLines+=list(i.values())
  


tokenized_sents = [word_tokenize(i) for i in listOfAllLines]

tokenized_sents
# Out:
# [['We',
#   'got',
#   'the',
#   'A3',
#   'because',
#   'it',
#   'was',
#   'fun',
#   'to',
#   'drive',
#   'and',
#   'was',
#   'a',
#   'luxury',
#   'wagon',
#   '.',
#   'Last',
#   'week',
#   'my',
#   'husband',
#   'was',
#   'stopped',
#   'in',
#   'traffic',
#   'on',
#   'the',
#   'highway',
#   'and',
#   'was',
#   'rear',
#   'ended',
#   'by',
#   'a',
#   'Dodge',
#   'Caravan',
#   'going',
#   '50-60',
#   'MPH',
#   '.',
#   'The',
#   'A3',
#   'is',
#   'a',
#   'total',
#   'loss',
#   'with',
#   'over',
#   '19,000',
#   'in',
#   'visual',
#   'damage',
#   'alone',
#   '.',
#   'The',
#   'safety',
#   'features',
#   'in',
#   'this',
#   'car',
#   'ca',
#   "n't",
#   'be',
#   'beat',
#   ',',
#   'while',
#   'my',
#   'husband',
#   'has',
#   'some',
#   'injuries',
#   'he',
#   'was',
#   'able',
#   'to',
#   'walk',
#   'away',
#   'from',
#   'a',
#   'serious',
#   'multi-vehicle',
#   'accident',
#   '.'],
#  ['I',
#   'bought',
# ...

# %%
arrayOfTokenizeSentences=list()
for i in tokenized_sents:
  tokenized=i
  lema=list()
  for j in tokenized:
    if (j not in Stopwords and j.isalnum()):
      lema.append(lemmatizer.lemmatize(j,pos=get_wordnet_pos(pos_tag(j)[0][0])))  
  arrayOfTokenizeSentences.append(lema)


wordDictionary=dict()
for i in arrayOfTokenizeSentences:
  for j in i:
    if j in wordDictionary:
      wordDictionary[j]= wordDictionary[j] + 1
    else:
      add={j:1}
      wordDictionary.update(add)
listOfKeysToPop=list()
for key in wordDictionary:
  if(wordDictionary[key] <= 6 ):
    listOfKeysToPop.append(key)
    
for i in listOfKeysToPop:
  wordDictionary.pop(i)

listOfValues=list()
listOfWords=list()
for i in (wordDictionary.values()) :  
     listOfValues.append(i)
for i in (wordDictionary.keys()) :  
     listOfWords.append(i)
listOfWords.reverse()
listOfValues.reverse()
print('Number of words:' + str (len(listOfWords)))

#listOfValues=listOfValues[ :20]
#listOfWords=listOfWords[ :20]

dataframe={'Word':listOfWords,'Value':listOfValues}
dataFrame=pd.DataFrame(dataframe)
dataFrame=dataFrame.sort_values(by=['Value'],ascending=False)
dataFrame=pd.DataFrame(dataFrame.head(20))

sns.set_theme(style="whitegrid")
plt.figure(figsize=(16, 6))
ax = sns.barplot(x=dataFrame.Word, y='Value', data=dataFrame)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-6c0fd7e7ce08> in <module>()
#       5   for j in tokenized:
#       6     if (j not in Stopwords and j.isalnum()):
# ----> 7       lema.append(lemmatizer.lemmatize(j,pos=get_wordnet_pos(pos_tag(j)[0][0])))
#       8   arrayOfTokenizeSentences.append(lema)
#       9
#
# /usr/local/lib/python3.7/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     132     """
#     133     tagger = _get_tagger(lang)
# --> 134     return _pos_tag(tokens, tagset, tagger)
#     135
#     136
#
# /usr/local/lib/python3.7/dist-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger)
#     100
#     101 def _pos_tag(tokens, tagset, tagger):
# --> 102     tagged_tokens = tagger.tag(tokens)
#     103     if tagset:
# ...

# %%
#sentiment creation

# %%
smallNumberOfReviews=list()
for i in range(0,1000):
  smallNumberOfReviews.append(tokenized_sents.pop(i))

ngramsDict=ngramFunc(smallNumberOfReviews,1) 

tokenized_sents.pop(1)

# %%
#Unigram

frequencyDict=dict()
valueOfAllUnigrams=0
for unigram in ngramsDict:
  valueOfAllUnigrams+=ngramsDict.get(unigram)
for unigram in ngramsDict:
  add={unigram:ngramsDict.get(unigram)/valueOfAllUnigrams}#this is where we add the frequency of occurence 
  frequencyDict.update(add)

list1=list(frequencyDict.values())

Avg=statistics.mean(list1)


finalDict=dict()
for unigram in frequencyDict:
  if (frequencyDict.get(unigram)>Avg):#We remove valuse that have less than average frequency
    add={unigram:frequencyDict.get(unigram)}
    finalDict.update(add)
unigramDict=finalDict

# %%
smallNumberOfReviews=list()
for i in range(0,1000):
  smallNumberOfReviews.append(tokenized_sents.pop(i))

ngramsDict=ngramFunc(smallNumberOfReviews,2) 

tokenized_sents.pop(1)
frequencyDict=dict()
valueOfAllBigrams=0
for bigram in ngramsDict:
  valueOfAllBigrams+=ngramsDict.get(bigram)
for bigram in ngramsDict:
  add={bigram:ngramsDict.get(bigram)/valueOfAllBigrams}#this is where we add the frequency of occurence 
  frequencyDict.update(add)

list1=list(frequencyDict.values())
Avg=statistics.mean(list1)


finalDict=dict()
for bigram in frequencyDict:
  if (frequencyDict.get(bigram)>Avg):#We remove valuse that have less than average frequency
    add={bigram:frequencyDict.get(bigram)}
    finalDict.update(add)
bigramDict=finalDict

# %%
listOfAllLines=list(listOfDirectories[1].values())#can add more sentences for data

tokenized_sents = [word_tokenize(i) for i in listOfAllLines]
dictOfTokens=dict()
index=1
for sentence in tokenized_sents:
  
  for word in sentence:
    word=word.lower()
    word=word.rstrip("\n")
    if (word in dictOfTokens):
      continue
    else:
      add={word:index}
      dictOfTokens.update(add)
      index+=1


listOfValuesForWords=list()
for sentence in tokenized_sents:
  newSentence=list()
  for word in sentence:
    word=word.lower()
    word=word.rstrip("\n")
    value=dictOfTokens[word]
    newSentence.append(value)
  listOfValuesForWords.append(newSentence)      


listOfValuesForWords=pad_sequences(listOfValuesForWords, 10)
y=[value[0] for value in listOfValuesForWords ]
X=listOfValuesForWords
#getSizeOfVocab(listOfValuesForWords)[-1:]

# %%
listOfAllLines

# %%
trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.1, random_state=1)

trainX, valX, trainY, valY= train_test_split(trainX, trainY, test_size=0.11111111, random_state=1)

trainX = np.array(trainX)

testX = np.array(testX)

valX = np.array(valX)
valY = np.array(valY)
trainY = np.asarray(trainY).astype('float32').reshape((-1,1))
testY = np.asarray(testY).astype('float32').reshape((-1,1))
testY = np.array(testY)
trainY = np.array(trainY)

model = Sequential()
model.add(Embedding( input_dim=2249, output_dim=50))
model.add(LSTM(128, activation='sigmoid'))
model.add(Dense(4, activation='sigmoid'))
print(model.summary())

model.compile(loss='mean_squared_error',
              optimizer=Adam(0.00001),
              metrics=['accuracy'])

history = model.fit(x=trainX, y=trainY, epochs=3, validation_data=(valX, valY), verbose=1)

test_loss, test_acc = model.evaluate(testX, testY)

print('Test Loss: {}'.format(test_loss))
print('Test Accuracy: {}'.format(test_acc))

plot_loss(history)

# %%
pip install -q -U tensorflow-text

# %%
model='small_bert/bert_en_uncased_L-4_H-512_A-8' 
down='https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1'
down2='https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3'
bert_preprocess_model = hub.KerasLayer(down)
tfhub_handle_encoder = down
tfhub_handle_preprocess = down2

# %%
url = 'https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'

dataset = tf.keras.utils.get_file('aclImdb_v1.tar.gz', url,
                                  untar=True, cache_dir='.',
                                  cache_subdir='')

dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')

train_dir = os.path.join(dataset_dir, 'train')


remove_dir = os.path.join(train_dir, 'unsup')
shutil.rmtree(remove_dir)
AUTOTUNE = tf.data.AUTOTUNE
batch_size = 32
seed = 42

raw_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train',
    batch_size=batch_size,
    validation_split=0.2,
    subset='training',
    seed=seed)

class_names = raw_train_ds.class_names
train_ds = raw_train_ds.cache().prefetch(buffer_size=AUTOTUNE)

val_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train',
    batch_size=batch_size,
    validation_split=0.2,
    subset='validation',
    seed=seed)

val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/test',
    batch_size=batch_size)

test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def build_classifier_model():
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
  preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
  encoder_inputs = preprocessing_layer(text_input)
  encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
  outputs = encoder(encoder_inputs)
  net = outputs['pooled_output']
  net = tf.keras.layers.Dropout(0.1)(net)
  net = tf.keras.layers.Dense(1, activation=None, name='classifier')(net)
  return tf.keras.Model(text_input, net)

loss = tf.keras.losses.BinaryCrossentropy(from_logits=True)
metrics = tf.metrics.BinaryAccuracy()
epochs = 1
steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
num_train_steps = steps_per_epoch * epochs
num_warmup_steps = int(0.1*num_train_steps)

init_lr = 3e-5
optimizer = optimization.create_optimizer(init_lr=init_lr,
                                          num_train_steps=num_train_steps,
                                          num_warmup_steps=num_warmup_steps,
                                          optimizer_type='adamw')
classifier_model.compile(optimizer=optimizer,
                         loss=loss,
                         metrics=metrics)

# %%
print(f'Training model with {tfhub_handle_encoder}')
history = classifier_model.fit(x=train_ds,
                               validation_data=val_ds,
                               epochs=epochs)

# %%
loss, accuracy = classifier_model.evaluate(test_ds)

print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')

# %%
history_dict = history.history
print(history_dict.keys())

acc = history_dict['binary_accuracy']
val_acc = history_dict['val_binary_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)
fig = plt.figure(figsize=(10, 6))
fig.tight_layout()

plt.subplot(2, 1, 1)
# "bo" is for "blue dot"
plt.plot(epochs, loss, 'r', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
# plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
classifier_model.predict(listOfAllLines)

# %%
listOfAllLines

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
tokenized_texts = [tokenizer.tokenize(sent) for sent in listOfAllLines]

bert_model = TFBertModel.from_pretrained('bert-base-uncased')
albert_model = TFAlbertModel.from_pretrained('albert-base-v2')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# %%
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
albert_tokenizer = AlbertTokenizer.from_pretrained('albert-base-v2')
roberta_tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
distilbert_tokenizer =DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# %%
input_ids = pad_sequences([bert_tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                          maxlen=128, dtype="long", truncating="post", padding="post")
input_ids = [bert_tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
input_ids = pad_sequences(input_ids, maxlen=128, dtype="long", truncating="post", padding="post")
attention_masks = []
for seq in input_ids:
  seq_mask = [float(i>0) for i in seq]
  attention_masks.append(seq_mask)

train_inputs, validation_inputs, train_labels, validation_labels = train_test_split(input_ids, classes,random_state=2018, test_size=0.1)
train_masks, validation_masks, _, _ = train_test_split(attention_masks, input_ids,random_state=2018, test_size=0.1)

train_inputs = tf.convert_to_tensor(train_inputs, dtype=tf.float32)
validation_inputs = tf.convert_to_tensor(validation_inputs, dtype=tf.float32)
train_labels = tf.convert_to_tensor(train_labels, dtype=tf.float32)
validation_labels = tf.convert_to_tensor(validation_labels, dtype=tf.float32)
validation_inputs = tf.convert_to_tensor(validation_inputs, dtype=tf.float32)
validation_masks = tf.convert_to_tensor(validation_masks, dtype=tf.float32)
